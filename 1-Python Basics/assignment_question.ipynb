# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
user = input(print("give a user name "))
print(user)
# Out:
# give a user name
# hmida

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
a = int(input(print("give a number")))
                
if a>0:
    print("the number is positive")
elif a<0:
    print("the number is negative")
else:print("the number is zero")
# Out:
# give a number
# the number is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a=15
b=9
c=10

if a>b and a>c:
    print(a ,"is the largest")
elif b>a and b>c:
    print(b,"is the largest")
else :print(c,"is the largest")
# Out:
# 15 is the largest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
a=3
fac = 1
for i in range(1,a+1):
    fac *= i
print("factorial of ",a," = ",fac)
# Out:
# factorial of  3  =  6

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
integer_var = 10
float_var = 10.5
string_var = "Hello"
boolean_var = True

print(f"Integer value: {integer_var}, type: {type(integer_var)}")
print(f"Float value: {float_var}, type: {type(float_var)}")
print(f"String value: {string_var}, type: {type(string_var)}")
print(f"Boolean value: {boolean_var}, type: {type(boolean_var)}")
# Out:
# Integer value: 10, type: <class 'int'>
# Float value: 10.5, type: <class 'float'>
# String value: Hello, type: <class 'str'>
# Boolean value: True, type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
x=5
u=9
print("original: ",x,u)
x,u=u,x
print("after swaping: ",x,u)
# Out:
# original:  5 9
# after swaping:  9 5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
degree = int(input(print("give the degree in Celsius : ")))
fahrenheit = degree*(9/5) + 32
print(fahrenheit)
# Out:
# give the degree in Celsius :
# 46.4

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
a = "hello "
b = "yassmine"
print(a+b)
# Out:
# hello yassmine

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = 85.2

if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# 85.2 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a=1
b=6
c=3

print(f"addition : {a}+{b}+{c} = " , a+b+c)
print(f"subtraction : {b}-{c} = ",b-c)
print(f"multiplication : {b}*{c} = ",b*c)
print(f"division : {b}/{c} = ",b/c)
# Out:
# addition : 1+6+3 =  10
# subtraction : 6-3 =  3
# multiplication : 6*3 =  18
# division : 6/3 =  2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = True
b = False

print(f"{a} and {b} : {a and b}")
print(f"{a} or {b} : {a or b}")
print(f"not True : {not a}")
# Out:
# True and False : False
# True or False : True
# not True : False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = float(input(print("give a number : ")))
square = num**2
print(f"{num}**2 = {square}")
# Out:
# give a number :
# 5.0**2 = 25.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = float(input(print("give a number : ")))

if num % 2 == 0 :
    print(f"{num} is even")
else : print(f"{num} is odd")
# Out:
# give a number :
# 11.0 is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
n = int(input("Enter a number: "))
sum = 0
for i in range(1,n+1):
    sum+=i
print("sum = ",sum)
# Out:
# sum =  3

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
n = int(input("Enter a year: "))
if n % 400 == 0 :
    print(f"{n} is a leap year")
else : print(f"{n} is not a leap year")
# Out:
# 2000 is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = input("Enter a string: ")
reversed_string = string[::-1]
print(f"The reversed string is: {reversed_string}")
# Out:
# The reversed string is: enimssay

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = input("Enter a string: ")
reversed_string = string[::-1]

if string == reversed_string :
    print(f"The string  {string} is palindrome ")
else : print(f"The string  {string} is not palindrome ")
# Out:
# The string  dad is palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
'''num = int(input(print("unter a number : ")))
for i in range(0,num+1):
    print(i)
'''

numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Sorted list: [3, 5, 8]

# %%
print("heeeeeeeeeeeee")
# Out:
# heeeeeeeeeeeee
